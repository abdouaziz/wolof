# %% [markdown]
# <a href="https://colab.research.google.com/github/abdouaziz/wolof/blob/main/examples/wolof_asr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture 
# !pip install transformers

# %%
# !pip install wolof

# %%
# !gdown --id 1wRiwaQmGi3dotcPgs7-vKt-o9JBN4I-n
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wRiwaQmGi3dotcPgs7-vKt-o9JBN4I-n
# To: /content/ASR_WOLOF_data_dev_wav_03_WOL_03_lect_0004.wav
# 100% 120k/120k [00:00<00:00, 64.1MB/s]

# %%
from wolof.asr import Speech2Text
from IPython.display import Audio

# %%
asr = Speech2Text(model_name="abdouaziiz/wav2vec2-xls-r-300m-wolof")
# Out:
# Downloading:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/214 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/344 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/309 [00:00<?, ?B/s]

# %%
audio_file="/content/ASR_WOLOF_data_dev_wav_03_WOL_03_lect_0004.wav"

# %%
Audio(audio_file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prediction = asr(audio_file)

# %%
prediction
# Out:
# 'ndaxam mu ngi ne cocc ak téeméeri atam'
